# %% [markdown]
# # Defining API Keys and URLs

# %%
import requests
import json

# API keys
GOOGLE_API_KEY = "AIzaSyCgUumda62lSYjEKMQTJtSvxk2UlXIVdzg"
YELP_API_KEY = "AHw4onevVP1E2N1jdGv0xU8dMp2yY52XCxdNSVc2bhbotRfyJKvvemBXuEW3vjsyLx2A22idXD0fzYiiw5K7zkGNOSsYiIOo8XvhCsfYr3xsn3Jdc6fOOYftHANAZ3Yx"

# %%
# API URLs
GOOGLE_BASE_URL = "https://maps.googleapis.com/maps/api"
YELP_BASE_URL = "https://api.yelp.com/v3"

# %% [markdown]
# # Google Places API: Fetch Place Details with Additional Fields

# %%
import time
import requests

def get_google_places(api_key, location, radius, place_type):
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    results = []
    next_page_token = None

    while True:
        # API parameters
        params = {
            "key": api_key,
            "location": location,
            "radius": radius,
            "type": place_type,
        }
        if next_page_token:
            params["pagetoken"] = next_page_token

        # API request
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()

        # Add results to the list
        results.extend(data.get("results", []))

        # Check for next_page_token
        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break

        time.sleep(2)  # Wait for 2 seconds before the next request

    return results

# Google Places API Fetching Place Details
def get_google_place_details(api_key, place_id):
    url = f"{GOOGLE_BASE_URL}/place/details/json"
    params = {
        "key": api_key,
        "place_id": place_id,
        "fields": "name,formatted_address,rating,geometry,types,opening_hours,user_ratings_total,reviews"
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json().get("result", {})

# %% [markdown]
# # Yelp API: Extract Yelp Restaurant Details

# %%
def search_yelp_restaurant(api_key, location, term):
    url = f"{YELP_BASE_URL}/businesses/search"
    headers = {"Authorization": f"Bearer {api_key}"}
    params = {
        "location": location,
        "term": term,
        "limit": 10,
    }
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    return response.json().get("businesses", [])

# %%
# Validate Match Based on Lat/Lng
def is_match_by_location(google_lat, google_lng, yelp_lat, yelp_lng, threshold=0.01):
    return abs(google_lat - yelp_lat) <= threshold and abs(google_lng - yelp_lng) <= threshold

# %% [markdown]
# # Defining Main and Secondary Cuisines

# %%
# List of main cuisines
MAIN_CUISINES = [
    "Italian", "Chinese", "Mexican", "Indian", "Japanese", "Thai", "French",
    "Mediterranean", "Greek", "Korean", "Vietnamese", "Spanish", "American",
    "Lebanese", "Turkish", "Caribbean", "Middle Eastern", "Ethiopian", "Pizza", "Asian",
    "Cantonese", "Vegan", "Cuban", "Szechuan", "Ramen", "Russian"
]

# List of secondary cuisines
SECONDARY_TYPES = {
    "bakery": ["bakery", "bakeries"],
    "cafe": ["cafe", "coffee shop", "coffee"],
    "bagel": ["bagel"],
    "bar": ["bar", "bars"],
    "dessert": ["dessert", "desserts"],
    "burger": ["burger"],
    "steak": ["steak"],
    "lounge": ["lounge"],
    "hotel": ["hotel"],
    "diner": ["diner"],
    "seafood": ["seafood"]
}

# %%
def label_cuisine(categories):
    
    categories_lower = [category.lower() for category in categories]

    # Check for main cuisines
    for cuisine in MAIN_CUISINES:
        if any(cuisine.lower() in category for category in categories_lower):
            return cuisine

    # Check for secondary types
    for label, synonyms in SECONDARY_TYPES.items():
        if any(synonym in categories_lower for synonym in synonyms):
            return label

    return "Other"

# %%
import unicodedata

def clean_google_hours(hours):
    if not hours:
        return None
    # Normalize hours
    return [unicodedata.normalize("NFKC", hour) for hour in hours]

# %% [markdown]
# # Fetching Neighborhood Restaurant Data

# %%
def fetch_neighborhood_restaurants(location, radius, place_type, google_api_key, yelp_api_key):
    google_places = get_google_places(google_api_key, location, radius, place_type)
    enriched_restaurants = []

    for place in google_places[:50]:  # Limit to 50 restaurants per neighborhood
        place_details = get_google_place_details(google_api_key, place["place_id"])
        google_name = place_details.get("name")
        google_address = place_details.get("formatted_address")
        google_lat = place_details["geometry"]["location"]["lat"]
        google_lng = place_details["geometry"]["location"]["lng"]

        # Additional fields from Google
        google_hours = clean_google_hours(place_details.get("opening_hours", {}).get("weekday_text", []))
        google_reviews = place_details.get("reviews", [])
        google_popularity = place_details.get("user_ratings_total", 0)
        google_photos = [photo.get("photo_reference") for photo in place_details.get("photos", [])]

        # Review text and ratings
        google_review_data = [
            {
                "text": review.get("text", ""),
                "rating": review.get("rating", None)
            }
            for review in google_reviews
        ]

        # Search Yelp for matches
        yelp_results = search_yelp_restaurant(yelp_api_key, location, google_name)
        yelp_match = None

        # Validate matches by comparing lat/lng
        for yelp_result in yelp_results:
            yelp_lat = yelp_result["coordinates"]["latitude"]
            yelp_lng = yelp_result["coordinates"]["longitude"]
            if is_match_by_location(google_lat, google_lng, yelp_lat, yelp_lng):
                yelp_match = yelp_result
                break

        # Additional fields from Yelp
        yelp_categories = [category["title"] for category in yelp_match.get("categories", [])] if yelp_match else []
        yelp_transactions = yelp_match.get("transactions", []) if yelp_match else []
        yelp_menu_url = yelp_match.get("url", None) if yelp_match else None
        yelp_is_closed = yelp_match.get("is_closed", None) if yelp_match else None

        # Determine cuisine
        cuisine = label_cuisine(yelp_categories)

        # Merge
        enriched_restaurant = {
            "google": {
                "name": google_name,
                "address": google_address,
                "rating": place_details.get("rating"),
                "types": place_details.get("types"),
                "latitude": google_lat,
                "longitude": google_lng,
                "hours": google_hours,
                "review_count": google_popularity,
                "review_snippets": google_review_data,
            },
            "yelp": {
                "name": yelp_match.get("name") if yelp_match else None,
                "address": ", ".join(yelp_match.get("location", {}).get("display_address", [])) if yelp_match else None,
                "rating": yelp_match.get("rating") if yelp_match else None,
                "price": yelp_match.get("price") if yelp_match else None,
                "categories": yelp_categories,
                "review_count": yelp_match.get("review_count") if yelp_match else None,
                "latitude": yelp_match["coordinates"]["latitude"] if yelp_match else None,
                "longitude": yelp_match["coordinates"]["longitude"] if yelp_match else None,
                "transactions": yelp_transactions,
                "menu_url": yelp_menu_url,
                "is_closed": yelp_is_closed,
            } if yelp_match else "No Yelp match found",
            "cuisine": cuisine,
        }
        enriched_restaurants.append(enriched_restaurant)

    return enriched_restaurants

# %%
def fetch_all_neighborhoods(neighborhoods, place_type, google_api_key, yelp_api_key, output_file="partial_data.json"):
    all_data = {}
    try:
        for name, config in neighborhoods.items():
            location = config["location"]
            radius = config["radius"]
            print(f"Fetching restaurants for {name} (Radius: {radius}m)...")
            all_data[name] = fetch_neighborhood_restaurants(location, radius, place_type, google_api_key, yelp_api_key)
    except Exception as e:
        
        print(f"An error occurred: {e}")

        with open(output_file, "w") as f:
            json.dump(all_data, f, indent=4)
        print(f"Partially fetched data saved to {output_file}")

        raise e

    return all_data

# %% [markdown]
# # Fetching Restaurants Based on Location and Making API Calls

# %%
# Define radius and place type
place_type = "restaurant"

# Neighborhoods and their lat/lng coordinates with dynamic radius based on location
# Rebalanced neighborhoods
NEIGHBORHOODS_CALL_1 = {
    "West Village": {"location": "40.7359,-74.0036", "radius": 1000},  # 1 km
    "SoHo": {"location": "40.7233,-74.0030", "radius": 1000},         # 1 km
    "Lower East Side": {"location": "40.7150,-73.9843", "radius": 1000},  # 1 km
}

NEIGHBORHOODS_CALL_2 = {
    "Upper East Side": {"location": "40.7736,-73.9566", "radius": 2000},  # 2 km
    "Midtown": {"location": "40.7549,-73.9840", "radius": 1500},      # 1.5 km
    "Chinatown": {"location": "40.7158,-73.9970", "radius": 1000},    # 1 km
    "Upper West Side": {"location": "40.7870,-73.9754", "radius": 2000},  # 2 km
}

YELP_API_KEY_1 = "AHw4onevVP1E2N1jdGv0xU8dMp2yY52XCxdNSVc2bhbotRfyJKvvemBXuEW3vjsyLx2A22idXD0fzYiiw5K7zkGNOSsYiIOo8XvhCsfYr3xsn3Jdc6fOOYftHANAZ3Yx"
YELP_API_KEY_2 = "B0WdruultLblnBmOMDL-faee_-BhaKu1oyC13_WLmz_0CU3FXB82EEG9LAF2FSvkZFwJSmUGLytCsTSlXSD1yrrTsSlHX4tzbw8Z1rEv8JvS33yoA5ZtBPNBAfA_Z3Yx"

try:
    # Fetch data using different API keys
    all_neighborhood_data_1 = fetch_all_neighborhoods(NEIGHBORHOODS_CALL_1, place_type, GOOGLE_API_KEY, YELP_API_KEY_1, output_file="partial_data_call_1.json")
    all_neighborhood_data_2 = fetch_all_neighborhoods(NEIGHBORHOODS_CALL_2, place_type, GOOGLE_API_KEY, YELP_API_KEY_2, output_file="partial_data_call_2.json")

    all_neighborhood_data = {**all_neighborhood_data_1, **all_neighborhood_data_2}

    # Save to a JSON file
    output_file = "nyc_restaurants_7x50.json"
    with open(output_file, "w") as f:
        json.dump(all_neighborhood_data, f, indent=4)

    print(f"Restaurant details for all neighborhoods saved to {output_file}")

except Exception as e:
    print(f"Critical error: {e}")
# Out:
# Fetching restaurants for West Village (Radius: 1000m)...
# Fetching restaurants for SoHo (Radius: 1000m)...
# Fetching restaurants for Lower East Side (Radius: 1000m)...
# Fetching restaurants for Upper East Side (Radius: 2000m)...
# Fetching restaurants for Midtown (Radius: 1500m)...
# Fetching restaurants for Chinatown (Radius: 1000m)...
# Fetching restaurants for Upper West Side (Radius: 2000m)...
# Restaurant details for all neighborhoods saved to nyc_restaurants_7x50.json

# %%
import json

# List of main cuisines
MAIN_CUISINES = [
    "Italian", "Chinese", "Mexican", "Indian", "Japanese", "Thai", "French",
    "Mediterranean", "Greek", "Korean", "Vietnamese", "Spanish", "American",
    "Lebanese", "Turkish", "Caribbean", "Middle Eastern", "Ethiopian", "Pizza", "Asian",
    "Cantonese", "Vegan", "Cuban", "Szechuan", "Ramen", "Russian"
]

# List of secondary cuisines
SECONDARY_TYPES = {
    "bakery": ["bakery", "bakeries"],
    "cafe": ["cafe", "coffee shop", "coffee"],
    "bagel": ["bagel"],
    "bar": ["bar", "bars"],
    "dessert": ["dessert", "desserts"],
    "burger": ["burger"],
    "steak": ["steak"],
    "lounge": ["lounge"],
    "hotel": ["hotel"],
    "diner": ["diner"],
    "seafood": ["seafood"]
}

# Function to label cuisine based on categories
def label_cuisine(categories):
    # Check for main cuisines
    for cuisine in MAIN_CUISINES:
        if any(cuisine.lower() in category.lower() for category in categories):
            return cuisine

    # Check for secondary types
    for secondary, keywords in SECONDARY_TYPES.items():
        if any(keyword.lower() in category.lower() for keyword in keywords for category in categories):
            return secondary.capitalize()

    return "Other"

# Update cuisines in the dataset
def update_cuisines(data):
    for neighborhood, restaurants in data.items():
        for restaurant in restaurants:
            
            if restaurant["cuisine"] == "Other":
                # Combine Google and Yelp categories (if present)
                categories = restaurant["yelp"].get("categories", [])
                
                restaurant["cuisine"] = label_cuisine(categories)
    return data

# Read data from a JSON file
input_file = "nyc_restaurants_7x50.json" 
output_file = "updated_restaurants.json" 

with open(input_file, "r") as f:
    data = json.load(f)

# Update cuisines
updated_data = update_cuisines(data)

# Save the updated data to a new JSON file
with open(output_file, "w") as f:
    json.dump(updated_data, f, indent=4)

print(f"Updated data saved to {output_file}")
# Out:
# Updated data saved to updated_restaurants.json

# %% [markdown]
# # Flattening Data

# %%
import json

# Flatten and organize data
def organize_restaurant_data(data):
    organized_data = []
    
    for neighborhood, restaurants in data.items():
        for restaurant in restaurants:
            print(restaurant["google"]["name"])
            # Extract fields from Google and Yelp
            flattened_restaurant = {
                "neighborhood": neighborhood,
                "restaurant_name": restaurant["google"]["name"],
                "address": restaurant["google"]["address"],
                "rating_google": restaurant["google"]["rating"],
                "rating_yelp": restaurant["yelp"]["rating"],
                "review_count_google": restaurant["google"].get("review_count", 0),
                "review_count_yelp": restaurant["yelp"].get("review_count", 0),
                "categories": restaurant["yelp"].get("categories", []),  
                "latitude": restaurant["google"]["latitude"],
                "longitude": restaurant["google"]["longitude"],
                "hours": restaurant["google"].get("hours", []), 
                "transactions": restaurant["yelp"].get("transactions", []), 
                "menu_url": restaurant["yelp"].get("menu_url", None),
                "is_closed": restaurant["yelp"].get("is_closed", None),
                "cuisine": restaurant["cuisine"],
                "review_snippets_google": restaurant["google"].get("review_snippets", [])
            }
            organized_data.append(flattened_restaurant)
    
    return organized_data

# Loading original JSON data
input_file = "manhattan_restaurants.json"
with open(input_file, "r") as f:
    data = json.load(f)

organized_data = organize_restaurant_data(data)

# Saving flattened data to a new JSON file
output_file = "flattened_manhattan_restaurants.json"
with open(output_file, "w") as f:
    json.dump(organized_data, f, indent=4)

print(f"Flattened data saved to {output_file}")
# Out:
# Artichoke Basille's Pizza
# Magnolia Bakery
# Blue Note
# Dos Caminos
# Babbo
# STK Steakhouse
# Mighty Quinn's Barbeque
# One if by Land, Two if by Sea
# Waverly Inn
# Old Homestead Steakhouse
# The Taco Shop
# Little Owl
# Pastis
# The Tippler
# Palma
# John's of Bleecker Street
# Employees Only
# Blind Tiger
# L'Artusi
# Mermaid Oyster Bar
# Cafeteria
# Joe's Pizza
# Family Meal at Blue Hill
# Wilfie & Nell
# Buvette
# Murray's Bagels
# Morandi
# The Standard Grill
# Perry St
# ZiZi
# Hudson Clearwater
# Casa La Femme
# Amorino Gelato - New York Greenwich Village
# Mamoun's Falafel
# Off the Wagon
# Cafe Cluny
# taïm mediterranean kitchen
# Negril Village
# Empellon Taqueria & Bar
# Malatesta Trattoria
# Bobo
# Art Bar
# Gotham Restaurant
# White Horse Tavern
# Carbone New York
# 8th Street Winecellar
# Red Bamboo
# Gottino Enoteca e Salumeria
# Caliente Cab Co.
# Wallsé
# NOMO SOHO
# Artichoke Basille's Pizza
# The Frederick Hotel
# Gilligan's
# The Dutch
# Balthazar
# Lombardi's Pizza
# Dominique Ansel Bakery
# Tribeca Grill
# Cipriani Downtown - Restaurant
# Carbone New York
# Boqueria Soho
# Blue Note
# Macao Trading Company
# Locanda Verde Tribeca
# La Esquina Brasserie
# Bubby's
# Mermaid Oyster Bar
# Shuka
# Lure Fishbar
# Tacombi
# Wolfgang's Steakhouse
# Rubirosa
# Osteria Morini
# Ferrara Bakery & Cafe
# Café Habana
# Blue Ribbon Brasserie
# Katra Lounge & Event Space
# Negril Village
# Eileen's Special Cheesecake
# Chipotle Mexican Grill
# Joe's Pizza
# Starbucks
# The Red Lion
# Off the Wagon
# Palma
# Mamoun's Falafel
# The Grey Dog
# Lupa
# Parm Mulberry Street
# Aria Wine Bar
# Cafe Select
# The Odeon
# Tomo21 Sushi
# Cuba
# Whiskey Tavern
# Ear Inn
# The Brooklyneer
# Market Table
# Amity Hall Downtown
# Pianos
# Beauty & Essex
# Clinton St. Baking Company
# Hotel Chantelle
# The Delancey Rooftop
# Zest Sushi Izakaya
# Essex Restaurant
# Starbucks
# Congee Village
# Barrio Chino
# The Ten Bells
# Verlaine
# Hair of the Dog
# Essex Market
# Russ & Daughters
# Dirt Candy
# Supper
# Phở Grand
# Sauce Restaurant
# Golden Forest
# Bacaro
# Mehanata Bulgarian Bar
# La Caverna
# Bar Belly
# Cafe Katja
# Sticky Rice
# Home Sweet Home
# The DL | Best Rooftop Lounge NYC
# Jadis
# Grey Lady
# Tre
# Sammy's Roumanian Steak House
# The Skinny Bar and Lounge
# Poco NYC
# Souvlaki GR
# Blue Ribbon Sushi Izakaya
# Hi Thai
# Two Boots Pizza East Village
# Kossar's Bagels & Bialys (LES)
# Elevate
# Cocoron
# Pig and Khao
# Wolfnights - The Gourmet Wrap
# Makabely
# Cafe Himalaya
# 88 Palace
# Domino's Pizza
# Remedy Diner
# Iggy's Keltic Lounge
# Wa Lung Kitchen
# The Mark Hotel
# Park Lane Hotel New York
# Daniel
# Central Park Boathouse
# TAO Uptown
# Uva
# Lady M Cake Boutique - Upper East Side
# The Regency Bar & Grill
# E.A.T.
# Phoenix Park
# Land of Plenty
# Shake Shack Upper East Side
# Maya
# Cafe d’Alsace
# Starbucks
# Quality Meats
# Trattoria L'incontro
# Club A Steakhouse
# Café Boulud
# The Stumble Inn
# The Penrose Bar
# Akami
# Tony's Di Napoli
# Lips Drag Queen Show Palace Restaurant & Bar
# Shake Shack Upper West Side
# Orsay
# Dallas BBQ
# Club Macanudo
# P.J. Clarke's
# JG Melon
# Naruto Ramen
# Via Quadronno
# Scalinatella
# Philippe Chow
# Bamboo Sushi
# Gotham Pizza
# Hanabi
# Sushi of Gari UES
# Le Pain Quotidien
# Jackson Hole
# Domino's Pizza
# Nobu Fifty Seven
# JoJo by Jean-Georges
# Patsy's Pizzeria
# Aquavit
# Alice's Tea Cup
# Le Pain Quotidien
# Bella Blu
# Famous Original Ray's Pizza
# David Burke Tavern
# Kimpton Hotel Eventi
# Park Lane Hotel New York
# Connolly's
# Oohu Szechuan & Canton Cuisines
# Carmine's
# Bryant Park Grill
# Grand Central Oyster Bar
# Blue Fin
# Shake Shack Theater District
# Ellen's Stardust Diner
# Del Frisco's Double Eagle Steakhouse
# YOTEL New York Times Square
# Morton's The Steakhouse
# Keens Steakhouse
# Pershing Square
# Hard Rock Cafe
# Red Lobster
# Sophie's Cuban Cuisine - Midtown West
# Olive Garden Italian Restaurant
# Stout NYC
# The View Restaurant & Lounge
# The Capital Grille
# Dave & Buster's New York City - Times Square
# Ai Fiori
# Del Frisco's Grille
# Becco
# burger joint
# The Lambs Club
# Green Symphony
# Trattoria Trecolori
# Birdland Jazz Club
# Wolfgang's Steakhouse
# Havana Central Times Square
# McGee's Pub
# FIG & OLIVE
# STK Steakhouse
# Nobu Fifty Seven
# Tick Tock Diner NY
# The National Bar & Dining Rooms
# Café China
# fresh&co
# Oceana
# Victor's Cafe Cuban Restaurant
# Sushi Yasuda
# La Masseria NY
# The Yale Club
# Benjamin Steakhouse
# Bill's Bar & Burger
# The Russian Tea Room
# Marseille
# NOMO SOHO
# Lombardi's Pizza
# Balthazar
# La Esquina Brasserie
# Katra Lounge & Event Space
# Macao Trading Company
# Hotel Chantelle
# Ferrara Bakery & Cafe
# Zest Sushi Izakaya
# Golden Unicorn
# Osteria Morini
# Rubirosa
# Nom Wah Tea Parlor
# Eileen's Special Cheesecake
# Whiskey Tavern
# Dim Sum Go Go
# Café Habana
# Starbucks
# Congee Village
# Gilligan's
# Barrio Chino
# Supreme Restaurant
# The Ten Bells
# Starbucks
# Loreley Beer Garden
# Cafe Select
# Home Sweet Home
# Pianos
# Blue Agave Pulquería NYC | Mexican Restaurant & Agave Bar
# Dirt Candy
# The Grey Dog
# Phở Grand
# Parm Mulberry Street
# Essex Market
# La Mela
# Mikaku Sushi
# Elevate
# Tacombi
# Little Ruby's SoHo
# LuAnne's Wild Ginger
# Casa D' Angelo - Nyc
# Bacaro
# The Original Buddha Bodai Kosher Vegetarian Restaurant 佛菩提
# Da Nico Ristorante
# Golden Forest
# Cowgirl SeaHorse
# Bar Belly
# Jadis
# The Odeon
# Spring Lounge
# Hotel Belleclaire
# The Mark Hotel
# Central Park Boathouse
# Carmine's Italian Restaurant - Upper West Side
# Magnolia Bakery
# Shake Shack Upper West Side
# Jing Fong
# Alice's Tea Cup
# Lady M Cake Boutique - Upper East Side
# Sarabeth's Upper West Side
# Gray's Papaya
# Talia's Steakhouse and Bar
# E.A.T.
# Blondies Sports
# 5 Napkin Burger
# The Smith
# Lincoln Ristorante
# Cafe Luxembourg
# Peacefood - Upper West Side
# Amsterdam Ale House
# Bar Boulud
# P.J. Clarke's Lincoln Square
# Boulud Sud
# Prohibition
# Barney Greengrass
# Saravanaa Bhavan
# Rosa Mexicano
# Smoke Jazz & Supper Club
# Deli Kasbah Kosher Grill
# Flor de Mayo Restaurant
# Noi Due Cafe
# The Gin Mill
# Atlantic Grill
# Pomodoro Rosso
# Jake's Dilemma
# Cafe Fiorello
# El Mitote
# Land Thai Kitchen
# Osteria Cotta
# The Leopard at des Artistes
# Salumeria Rosi
# Pappardella
# The Dead Poet
# Le Pain Quotidien
# Ashford & Simpson's Sugar Bar
# Tavern On the Green
# Sushi of Gari UWS (Gari Columbus)
# Shun Lee West
# Dive 75
# Awash Ethiopian Restaurant
# Flattened data saved to flattened_manhattan_restaurants.json

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.10.tar.gz (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 2.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.10-cp311-cp311-macosx_11_0_arm64.whl size=132284 sha256=7e6bf8867dc68213d4f421268e886e0df67a6f4840cf0b0f3ad74a1924961f2c
#   Stored in directory: /Users/aditisirohi/Library/Caches/pip/wheels/d9/83/60/e9660320860aef3c38a67dea6ff9538e4cad76502cb39ed280
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10

# %% [markdown]
# # Establishing Connection to Database

# %%
import psycopg2

# Database connection details
DB_HOST = "restaurantdb.c3ka6a2sic3o.us-east-2.rds.amazonaws.com" 
DB_PORT = 5432
DB_NAME = "postgres"
DB_USER = "aditisirohi" 
DB_PASSWORD = "****" 

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD
)
cur = conn.cursor()

# %% [markdown]
# # SQL for creating tables
#
# ### Create the restaurants table
# CREATE TABLE restaurants (
#     restaurant_id SERIAL PRIMARY KEY,
#     neighborhood VARCHAR(255),
#     restaurant_name VARCHAR(255),
#     address TEXT,
#     rating_google NUMERIC(3, 2),
#     rating_yelp NUMERIC(3, 2),
#     review_count_google INTEGER,
#     review_count_yelp INTEGER,
#     latitude NUMERIC(9, 6),
#     longitude NUMERIC(9, 6),
#     menu_url TEXT,
#     is_closed BOOLEAN,
#     cuisine VARCHAR(255)
# );
#
# ### Create the hours table
# CREATE TABLE hours (
#     hour_id SERIAL PRIMARY KEY,
#     restaurant_id INTEGER REFERENCES restaurants(restaurant_id) ON DELETE CASCADE,
#     weekday VARCHAR(50),
#     opening_hours TIME,
#     closing_hours TIME
# );
#
# ### Create the transactions table
# CREATE TABLE transactions (
#     transaction_id SERIAL PRIMARY KEY,
#     restaurant_id INTEGER REFERENCES restaurants(restaurant_id) ON DELETE CASCADE,
#     transaction_type VARCHAR(50)
# );
#
# ### Create the reviews table
# CREATE TABLE reviews (
#     review_id SERIAL PRIMARY KEY,
#     restaurant_id INTEGER REFERENCES restaurants(restaurant_id) ON DELETE CASCADE,
#     review_text TEXT,
#     review_rating INTEGER
# );
#
# ### Create the categories table
# CREATE TABLE categories (
#     category_id SERIAL PRIMARY KEY,
#     restaurant_id INTEGER REFERENCES restaurants(restaurant_id) ON DELETE CASCADE,
#     category_name VARCHAR(255)
# );

# %%
import psycopg2
from datetime import datetime

# Database connection details
DB_HOST = "restaurantdb.c3ka6a2sic3o.us-east-2.rds.amazonaws.com" 
DB_PORT = 5432
DB_NAME = "postgres"
DB_USER = "aditisirohi"  
DB_PASSWORD = "****" 

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD
)
cursor = conn.cursor()

# %% [markdown]
# # Inserting All Data into Database Tables

# %%
import psycopg2
from datetime import datetime

# Insert restaurant data
def insert_restaurant(cursor, restaurant):
    cursor.execute(
        """
        INSERT INTO restaurants (neighborhood, restaurant_name, address, rating_google, rating_yelp,
                                 review_count_google, review_count_yelp, latitude, longitude,
                                 menu_url, is_closed, cuisine)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        RETURNING restaurant_id
        """,
        (
            restaurant["neighborhood"],
            restaurant["restaurant_name"],
            restaurant["address"],
            restaurant["rating_google"],
            restaurant["rating_yelp"],
            restaurant["review_count_google"],
            restaurant["review_count_yelp"],
            restaurant["latitude"],
            restaurant["longitude"],
            restaurant["menu_url"],
            restaurant["is_closed"],
            restaurant["cuisine"]
        )
    )
    return cursor.fetchone()[0]

# Insert hours data
def insert_hours(cursor, restaurant_id, hours):
    for hour in hours:
        try:
            
            if "Closed" in hour:
                continue

            
            weekday, hours_str = hour.split(": ", 1)

            # Handle "Open 24 hours"
            if "Open 24 hours" in hours_str:
                opening_time = "00:00:00"
                closing_time = "23:59:59"
                cursor.execute(
                    """
                    INSERT INTO hours (restaurant_id, weekday, opening_hours, closing_hours)
                    VALUES (%s, %s, %s, %s)
                    """,
                    (restaurant_id, weekday.strip(), opening_time, closing_time)
                )
                continue

            # Handle multiple time ranges separated by commas
            time_ranges = hours_str.split(", ")
            for time_range in time_ranges:
                try:
                    opening, closing = time_range.split(" – ")

                    # Ensure both opening and closing hours have AM/PM
                    def ensure_am_pm(time_str):
                        if "AM" in time_str or "PM" in time_str:
                            return time_str
                        return f"{time_str} AM" if int(time_str.split(":")[0]) < 12 else f"{time_str} PM"

                    
                    opening = ensure_am_pm(opening.strip())
                    closing = ensure_am_pm(closing.strip())

                    # Convert to 24-hour format
                    opening_time = datetime.strptime(opening, "%I:%M %p").time()
                    closing_time = datetime.strptime(closing, "%I:%M %p").time()

                    cursor.execute(
                        """
                        INSERT INTO hours (restaurant_id, weekday, opening_hours, closing_hours)
                        VALUES (%s, %s, %s, %s)
                        """,
                        (restaurant_id, weekday.strip(), opening_time, closing_time)
                    )
                except ValueError:
                    print(f"Unexpected format for restaurant_id {restaurant_id}: {hour}")
                    continue

        except Exception as e:
            print(f"Error parsing hours for restaurant_id {restaurant_id}: {e}")

# Insert transactions data
def insert_transactions(cursor, restaurant_id, transactions):
    for transaction in transactions:
        cursor.execute(
            """
            INSERT INTO transactions (restaurant_id, transaction_type)
            VALUES (%s, %s)
            """,
            (restaurant_id, transaction)
        )

# Insert reviews data
def insert_reviews(cursor, restaurant_id, reviews):
    for review in reviews:
        cursor.execute(
            """
            INSERT INTO reviews (restaurant_id, review_text, review_rating)
            VALUES (%s, %s, %s)
            """,
            (restaurant_id, review["text"], review["rating"])
        )

# Insert categories data
def insert_categories(cursor, restaurant_id, categories):
    for category in categories:
        cursor.execute(
            """
            INSERT INTO categories (restaurant_id, category_name)
            VALUES (%s, %s)
            """,
            (restaurant_id, category)
        )

# Process the JSON file and insert data
def process_and_insert_data(file_path):
    with open(file_path, "r") as f:
        data = json.load(f)

    count = 0
    for restaurant in data:
        try:
            # Insert into restaurants and get restaurant_id
            restaurant_id = insert_restaurant(cursor, restaurant)

            # Insert related data
            if "hours" in restaurant and restaurant["hours"]:
                insert_hours(cursor, restaurant_id, restaurant["hours"])
            if "transactions" in restaurant and restaurant["transactions"]:
                insert_transactions(cursor, restaurant_id, restaurant["transactions"])
            if "review_snippets_google" in restaurant and restaurant["review_snippets_google"]:
                insert_reviews(cursor, restaurant_id, restaurant["review_snippets_google"])
            if "categories" in restaurant and restaurant["categories"]:
                insert_categories(cursor, restaurant_id, restaurant["categories"])

            # Commit after processing each restaurant
            conn.commit()
            count += 1
            print(f"Inserted data for restaurant {count}: {restaurant['restaurant_name']}")

        except Exception as e:
            
            conn.rollback()
            print(f"Error processing restaurant: {restaurant['restaurant_name']} - {e}")

# Function call with the flattened JSON file
process_and_insert_data("flattened_manhattan_restaurants.json")
# Out:
# Inserted data for restaurant 1: Artichoke Basille's Pizza
# Inserted data for restaurant 2: Magnolia Bakery
# Inserted data for restaurant 3: Blue Note
# Inserted data for restaurant 4: Dos Caminos
# Inserted data for restaurant 5: Babbo
# Inserted data for restaurant 6: STK Steakhouse
# Inserted data for restaurant 7: Mighty Quinn's Barbeque
# Inserted data for restaurant 8: One if by Land, Two if by Sea
# Inserted data for restaurant 9: Waverly Inn
# Inserted data for restaurant 10: Old Homestead Steakhouse
# Inserted data for restaurant 11: The Taco Shop
# Inserted data for restaurant 12: Little Owl
# Inserted data for restaurant 13: Pastis
# Inserted data for restaurant 14: The Tippler
# Inserted data for restaurant 15: Palma
# Inserted data for restaurant 16: John's of Bleecker Street
# Inserted data for restaurant 17: Employees Only
# Inserted data for restaurant 18: Blind Tiger
# Inserted data for restaurant 19: L'Artusi
# Inserted data for restaurant 20: Mermaid Oyster Bar
# Inserted data for restaurant 21: Cafeteria
# Inserted data for restaurant 22: Joe's Pizza
# Inserted data for restaurant 23: Family Meal at Blue Hill
# Inserted data for restaurant 24: Wilfie & Nell
# Inserted data for restaurant 25: Buvette
# Inserted data for restaurant 26: Murray's Bagels
# Inserted data for restaurant 27: Morandi
# Inserted data for restaurant 28: The Standard Grill
# Inserted data for restaurant 29: Perry St
# Inserted data for restaurant 30: ZiZi
# Inserted data for restaurant 31: Hudson Clearwater
# Inserted data for restaurant 32: Casa La Femme
# Inserted data for restaurant 33: Amorino Gelato - New York Greenwich Village
# Inserted data for restaurant 34: Mamoun's Falafel
# Inserted data for restaurant 35: Off the Wagon
# Inserted data for restaurant 36: Cafe Cluny
# Inserted data for restaurant 37: taïm mediterranean kitchen
# Inserted data for restaurant 38: Negril Village
# Inserted data for restaurant 39: Empellon Taqueria & Bar
# Inserted data for restaurant 40: Malatesta Trattoria
# Inserted data for restaurant 41: Bobo
# Inserted data for restaurant 42: Art Bar
# Inserted data for restaurant 43: Gotham Restaurant
# Inserted data for restaurant 44: White Horse Tavern
# Inserted data for restaurant 45: Carbone New York
# Inserted data for restaurant 46: 8th Street Winecellar
# Inserted data for restaurant 47: Red Bamboo
# Inserted data for restaurant 48: Gottino Enoteca e Salumeria
# Inserted data for restaurant 49: Caliente Cab Co.
# Inserted data for restaurant 50: Wallsé
# Inserted data for restaurant 51: NOMO SOHO
# Inserted data for restaurant 52: Artichoke Basille's Pizza
# Inserted data for restaurant 53: The Frederick Hotel
# Inserted data for restaurant 54: Gilligan's
# Inserted data for restaurant 55: The Dutch
# Inserted data for restaurant 56: Balthazar
# Inserted data for restaurant 57: Lombardi's Pizza
# Inserted data for restaurant 58: Dominique Ansel Bakery
# Inserted data for restaurant 59: Tribeca Grill
# Inserted data for restaurant 60: Cipriani Downtown - Restaurant
# Inserted data for restaurant 61: Carbone New York
# Inserted data for restaurant 62: Boqueria Soho
# Inserted data for restaurant 63: Blue Note
# Inserted data for restaurant 64: Macao Trading Company
# Inserted data for restaurant 65: Locanda Verde Tribeca
# Inserted data for restaurant 66: La Esquina Brasserie
# Inserted data for restaurant 67: Bubby's
# Inserted data for restaurant 68: Mermaid Oyster Bar
# Inserted data for restaurant 69: Shuka
# Inserted data for restaurant 70: Lure Fishbar
# Inserted data for restaurant 71: Tacombi
# Inserted data for restaurant 72: Wolfgang's Steakhouse
# Inserted data for restaurant 73: Rubirosa
# Inserted data for restaurant 74: Osteria Morini
# Inserted data for restaurant 75: Ferrara Bakery & Cafe
# Inserted data for restaurant 76: Café Habana
# Inserted data for restaurant 77: Blue Ribbon Brasserie
# Inserted data for restaurant 78: Katra Lounge & Event Space
# Inserted data for restaurant 79: Negril Village
# Inserted data for restaurant 80: Eileen's Special Cheesecake
# Inserted data for restaurant 81: Chipotle Mexican Grill
# Inserted data for restaurant 82: Joe's Pizza
# Inserted data for restaurant 83: Starbucks
# Inserted data for restaurant 84: The Red Lion
# Inserted data for restaurant 85: Off the Wagon
# Inserted data for restaurant 86: Palma
# Inserted data for restaurant 87: Mamoun's Falafel
# Inserted data for restaurant 88: The Grey Dog
# Inserted data for restaurant 89: Lupa
# Inserted data for restaurant 90: Parm Mulberry Street
# Inserted data for restaurant 91: Aria Wine Bar
# Inserted data for restaurant 92: Cafe Select
# Inserted data for restaurant 93: The Odeon
# Inserted data for restaurant 94: Tomo21 Sushi
# Inserted data for restaurant 95: Cuba
# Inserted data for restaurant 96: Whiskey Tavern
# Inserted data for restaurant 97: Ear Inn
# Inserted data for restaurant 98: The Brooklyneer
# Inserted data for restaurant 99: Market Table
# Inserted data for restaurant 100: Amity Hall Downtown
# Inserted data for restaurant 101: Pianos
# Inserted data for restaurant 102: Beauty & Essex
# Inserted data for restaurant 103: Clinton St. Baking Company
# Inserted data for restaurant 104: Hotel Chantelle
# Inserted data for restaurant 105: The Delancey Rooftop
# Inserted data for restaurant 106: Zest Sushi Izakaya
# Inserted data for restaurant 107: Essex Restaurant
# Inserted data for restaurant 108: Starbucks
# Inserted data for restaurant 109: Congee Village
# Inserted data for restaurant 110: Barrio Chino
# Inserted data for restaurant 111: The Ten Bells
# Inserted data for restaurant 112: Verlaine
# Inserted data for restaurant 113: Hair of the Dog
# Inserted data for restaurant 114: Essex Market
# Inserted data for restaurant 115: Russ & Daughters
# Inserted data for restaurant 116: Dirt Candy
# Inserted data for restaurant 117: Supper
# Inserted data for restaurant 118: Phở Grand
# Inserted data for restaurant 119: Sauce Restaurant
# Inserted data for restaurant 120: Golden Forest
# Inserted data for restaurant 121: Bacaro
# Inserted data for restaurant 122: Mehanata Bulgarian Bar
# Inserted data for restaurant 123: La Caverna
# Inserted data for restaurant 124: Bar Belly
# Inserted data for restaurant 125: Cafe Katja
# Inserted data for restaurant 126: Sticky Rice
# Inserted data for restaurant 127: Home Sweet Home
# Inserted data for restaurant 128: The DL | Best Rooftop Lounge NYC
# Inserted data for restaurant 129: Jadis
# Inserted data for restaurant 130: Grey Lady
# Inserted data for restaurant 131: Tre
# Inserted data for restaurant 132: Sammy's Roumanian Steak House
# Inserted data for restaurant 133: The Skinny Bar and Lounge
# Inserted data for restaurant 134: Poco NYC
# Inserted data for restaurant 135: Souvlaki GR
# Inserted data for restaurant 136: Blue Ribbon Sushi Izakaya
# Inserted data for restaurant 137: Hi Thai
# Inserted data for restaurant 138: Two Boots Pizza East Village
# Inserted data for restaurant 139: Kossar's Bagels & Bialys (LES)
# Inserted data for restaurant 140: Elevate
# Inserted data for restaurant 141: Cocoron
# Inserted data for restaurant 142: Pig and Khao
# Inserted data for restaurant 143: Wolfnights - The Gourmet Wrap
# Inserted data for restaurant 144: Makabely
# Inserted data for restaurant 145: Cafe Himalaya
# Inserted data for restaurant 146: 88 Palace
# Inserted data for restaurant 147: Domino's Pizza
# Inserted data for restaurant 148: Remedy Diner
# Inserted data for restaurant 149: Iggy's Keltic Lounge
# Inserted data for restaurant 150: Wa Lung Kitchen
# Inserted data for restaurant 151: The Mark Hotel
# Inserted data for restaurant 152: Park Lane Hotel New York
# Inserted data for restaurant 153: Daniel
# Inserted data for restaurant 154: Central Park Boathouse
# Inserted data for restaurant 155: TAO Uptown
# Inserted data for restaurant 156: Uva
# Inserted data for restaurant 157: Lady M Cake Boutique - Upper East Side
# Inserted data for restaurant 158: The Regency Bar & Grill
# Inserted data for restaurant 159: E.A.T.
# Inserted data for restaurant 160: Phoenix Park
# Inserted data for restaurant 161: Land of Plenty
# Inserted data for restaurant 162: Shake Shack Upper East Side
# Inserted data for restaurant 163: Maya
# Inserted data for restaurant 164: Cafe d’Alsace
# Inserted data for restaurant 165: Starbucks
# Inserted data for restaurant 166: Quality Meats
# Inserted data for restaurant 167: Trattoria L'incontro
# Inserted data for restaurant 168: Club A Steakhouse
# Inserted data for restaurant 169: Café Boulud
# Inserted data for restaurant 170: The Stumble Inn
# Inserted data for restaurant 171: The Penrose Bar
# Inserted data for restaurant 172: Akami
# Inserted data for restaurant 173: Tony's Di Napoli
# Inserted data for restaurant 174: Lips Drag Queen Show Palace Restaurant & Bar
# Inserted data for restaurant 175: Shake Shack Upper West Side
# Inserted data for restaurant 176: Orsay
# Inserted data for restaurant 177: Dallas BBQ
# Inserted data for restaurant 178: Club Macanudo
# Inserted data for restaurant 179: P.J. Clarke's
# Inserted data for restaurant 180: JG Melon
# Inserted data for restaurant 181: Naruto Ramen
# Inserted data for restaurant 182: Via Quadronno
# Inserted data for restaurant 183: Scalinatella
# Inserted data for restaurant 184: Philippe Chow
# Inserted data for restaurant 185: Bamboo Sushi
# Inserted data for restaurant 186: Gotham Pizza
# Inserted data for restaurant 187: Hanabi
# Inserted data for restaurant 188: Sushi of Gari UES
# Inserted data for restaurant 189: Le Pain Quotidien
# Inserted data for restaurant 190: Jackson Hole
# Inserted data for restaurant 191: Domino's Pizza
# Inserted data for restaurant 192: Nobu Fifty Seven
# Inserted data for restaurant 193: JoJo by Jean-Georges
# Inserted data for restaurant 194: Patsy's Pizzeria
# Inserted data for restaurant 195: Aquavit
# Inserted data for restaurant 196: Alice's Tea Cup
# Inserted data for restaurant 197: Le Pain Quotidien
# Inserted data for restaurant 198: Bella Blu
# Inserted data for restaurant 199: Famous Original Ray's Pizza
# Inserted data for restaurant 200: David Burke Tavern
# Inserted data for restaurant 201: Kimpton Hotel Eventi
# Inserted data for restaurant 202: Park Lane Hotel New York
# Inserted data for restaurant 203: Connolly's
# Inserted data for restaurant 204: Oohu Szechuan & Canton Cuisines
# Inserted data for restaurant 205: Carmine's
# Inserted data for restaurant 206: Bryant Park Grill
# Inserted data for restaurant 207: Grand Central Oyster Bar
# Inserted data for restaurant 208: Blue Fin
# Inserted data for restaurant 209: Shake Shack Theater District
# Inserted data for restaurant 210: Ellen's Stardust Diner
# Inserted data for restaurant 211: Del Frisco's Double Eagle Steakhouse
# Inserted data for restaurant 212: YOTEL New York Times Square
# Inserted data for restaurant 213: Morton's The Steakhouse
# Inserted data for restaurant 214: Keens Steakhouse
# Inserted data for restaurant 215: Pershing Square
# Inserted data for restaurant 216: Hard Rock Cafe
# Inserted data for restaurant 217: Red Lobster
# Inserted data for restaurant 218: Sophie's Cuban Cuisine - Midtown West
# Inserted data for restaurant 219: Olive Garden Italian Restaurant
# Inserted data for restaurant 220: Stout NYC
# Inserted data for restaurant 221: The View Restaurant & Lounge
# Inserted data for restaurant 222: The Capital Grille
# Inserted data for restaurant 223: Dave & Buster's New York City - Times Square
# Inserted data for restaurant 224: Ai Fiori
# Inserted data for restaurant 225: Del Frisco's Grille
# Inserted data for restaurant 226: Becco
# Inserted data for restaurant 227: burger joint
# Inserted data for restaurant 228: The Lambs Club
# Inserted data for restaurant 229: Green Symphony
# Inserted data for restaurant 230: Trattoria Trecolori
# Inserted data for restaurant 231: Birdland Jazz Club
# Inserted data for restaurant 232: Wolfgang's Steakhouse
# Inserted data for restaurant 233: Havana Central Times Square
# Inserted data for restaurant 234: McGee's Pub
# Inserted data for restaurant 235: FIG & OLIVE
# Inserted data for restaurant 236: STK Steakhouse
# Inserted data for restaurant 237: Nobu Fifty Seven
# Inserted data for restaurant 238: Tick Tock Diner NY
# Inserted data for restaurant 239: The National Bar & Dining Rooms
# Inserted data for restaurant 240: Café China
# Inserted data for restaurant 241: fresh&co
# Inserted data for restaurant 242: Oceana
# Inserted data for restaurant 243: Victor's Cafe Cuban Restaurant
# Inserted data for restaurant 244: Sushi Yasuda
# Inserted data for restaurant 245: La Masseria NY
# Inserted data for restaurant 246: The Yale Club
# Inserted data for restaurant 247: Benjamin Steakhouse
# Inserted data for restaurant 248: Bill's Bar & Burger
# Inserted data for restaurant 249: The Russian Tea Room
# Inserted data for restaurant 250: Marseille
# Inserted data for restaurant 251: NOMO SOHO
# Inserted data for restaurant 252: Lombardi's Pizza
# Inserted data for restaurant 253: Balthazar
# Inserted data for restaurant 254: La Esquina Brasserie
# Inserted data for restaurant 255: Katra Lounge & Event Space
# Inserted data for restaurant 256: Macao Trading Company
# Inserted data for restaurant 257: Hotel Chantelle
# Inserted data for restaurant 258: Ferrara Bakery & Cafe
# Inserted data for restaurant 259: Zest Sushi Izakaya
# Inserted data for restaurant 260: Golden Unicorn
# Inserted data for restaurant 261: Osteria Morini
# Inserted data for restaurant 262: Rubirosa
# Inserted data for restaurant 263: Nom Wah Tea Parlor
# Inserted data for restaurant 264: Eileen's Special Cheesecake
# Inserted data for restaurant 265: Whiskey Tavern
# Inserted data for restaurant 266: Dim Sum Go Go
# Inserted data for restaurant 267: Café Habana
# Inserted data for restaurant 268: Starbucks
# Inserted data for restaurant 269: Congee Village
# Inserted data for restaurant 270: Gilligan's
# Inserted data for restaurant 271: Barrio Chino
# Inserted data for restaurant 272: Supreme Restaurant
# Inserted data for restaurant 273: The Ten Bells
# Inserted data for restaurant 274: Starbucks
# Inserted data for restaurant 275: Loreley Beer Garden
# Inserted data for restaurant 276: Cafe Select
# Inserted data for restaurant 277: Home Sweet Home
# Inserted data for restaurant 278: Pianos
# Inserted data for restaurant 279: Blue Agave Pulquería NYC | Mexican Restaurant & Agave Bar
# Inserted data for restaurant 280: Dirt Candy
# Inserted data for restaurant 281: The Grey Dog
# Inserted data for restaurant 282: Phở Grand
# Inserted data for restaurant 283: Parm Mulberry Street
# Inserted data for restaurant 284: Essex Market
# Inserted data for restaurant 285: La Mela
# Inserted data for restaurant 286: Mikaku Sushi
# Inserted data for restaurant 287: Elevate
# Inserted data for restaurant 288: Tacombi
# Inserted data for restaurant 289: Little Ruby's SoHo
# Inserted data for restaurant 290: LuAnne's Wild Ginger
# Inserted data for restaurant 291: Casa D' Angelo - Nyc
# Inserted data for restaurant 292: Bacaro
# Inserted data for restaurant 293: The Original Buddha Bodai Kosher Vegetarian Restaurant 佛菩提
# Inserted data for restaurant 294: Da Nico Ristorante
# Inserted data for restaurant 295: Golden Forest
# Inserted data for restaurant 296: Cowgirl SeaHorse
# Inserted data for restaurant 297: Bar Belly
# Inserted data for restaurant 298: Jadis
# Inserted data for restaurant 299: The Odeon
# Inserted data for restaurant 300: Spring Lounge
# Inserted data for restaurant 301: Hotel Belleclaire
# Inserted data for restaurant 302: The Mark Hotel
# Inserted data for restaurant 303: Central Park Boathouse
# Inserted data for restaurant 304: Carmine's Italian Restaurant - Upper West Side
# Inserted data for restaurant 305: Magnolia Bakery
# Inserted data for restaurant 306: Shake Shack Upper West Side
# Inserted data for restaurant 307: Jing Fong
# Inserted data for restaurant 308: Alice's Tea Cup
# Inserted data for restaurant 309: Lady M Cake Boutique - Upper East Side
# Inserted data for restaurant 310: Sarabeth's Upper West Side
# Inserted data for restaurant 311: Gray's Papaya
# Inserted data for restaurant 312: Talia's Steakhouse and Bar
# Inserted data for restaurant 313: E.A.T.
# Inserted data for restaurant 314: Blondies Sports
# Inserted data for restaurant 315: 5 Napkin Burger
# Inserted data for restaurant 316: The Smith
# Inserted data for restaurant 317: Lincoln Ristorante
# Inserted data for restaurant 318: Cafe Luxembourg
# Inserted data for restaurant 319: Peacefood - Upper West Side
# Inserted data for restaurant 320: Amsterdam Ale House
# Inserted data for restaurant 321: Bar Boulud
# Inserted data for restaurant 322: P.J. Clarke's Lincoln Square
# Inserted data for restaurant 323: Boulud Sud
# Inserted data for restaurant 324: Prohibition
# Inserted data for restaurant 325: Barney Greengrass
# Inserted data for restaurant 326: Saravanaa Bhavan
# Inserted data for restaurant 327: Rosa Mexicano
# Inserted data for restaurant 328: Smoke Jazz & Supper Club
# Inserted data for restaurant 329: Deli Kasbah Kosher Grill
# Inserted data for restaurant 330: Flor de Mayo Restaurant
# Inserted data for restaurant 331: Noi Due Cafe
# Inserted data for restaurant 332: The Gin Mill
# Inserted data for restaurant 333: Atlantic Grill
# Inserted data for restaurant 334: Pomodoro Rosso
# Inserted data for restaurant 335: Jake's Dilemma
# Inserted data for restaurant 336: Cafe Fiorello
# Inserted data for restaurant 337: El Mitote
# Inserted data for restaurant 338: Land Thai Kitchen
# Inserted data for restaurant 339: Osteria Cotta
# Inserted data for restaurant 340: The Leopard at des Artistes
# Inserted data for restaurant 341: Salumeria Rosi
# Inserted data for restaurant 342: Pappardella
# Inserted data for restaurant 343: The Dead Poet
# Inserted data for restaurant 344: Le Pain Quotidien
# Inserted data for restaurant 345: Ashford & Simpson's Sugar Bar
# Inserted data for restaurant 346: Tavern On the Green
# Inserted data for restaurant 347: Sushi of Gari UWS (Gari Columbus)
# Inserted data for restaurant 348: Shun Lee West
# Inserted data for restaurant 349: Dive 75
# Inserted data for restaurant 350: Awash Ethiopian Restaurant

# %%
# Close the database connection
cursor.close()
conn.close()
